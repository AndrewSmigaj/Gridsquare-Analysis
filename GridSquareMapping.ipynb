# %%
import plotly.io as pio
import plotly.express as px
import pandas as pd
import json
import suntime
import regex 
import maidenhead
from datetime import datetime
import time

# %%
pio.renderers.default='browser'

# %%
#VARIABLES

testGridSquare = "CN96rp"
testSquare = maidenhead.to_location(testGridSquare, center=True)

#maidenhead returns 
gridWidthInLong = 2;
gridHeightInLat = 1;

# %%
#dataframe to hold log data
logDF = pd.DataFrame(columns=['Callsign', 'GridSquare', 'GridSubSquare', 'Time'])


#read in WSJT's All.txt decoded message log
with open("C:/Users/cutup/AppData/Local/WSJT-X/ALL.txt") as FT8Log:
    lines = FT8Log.readlines()
    
#regex based callsign and gridsquare extraction
for line in lines[:]:
    
    match = ""
    gridSq = ""
    
    #callsign matches (international)
    matches = regex.findall("[a-zA-Z0-9]{1,3}[0-9][a-zA-Z0-9]{0,3}[a-zA-Z]", line)
    
    #if two call signs are heard we take the latter as this is the message sender replying
    if len(matches) > 1:
        match = matches[1]
    elif len(matches) == 1:
        match = matches[0]
    
    #gridsquare match
    if(match != ""):
        gridSqMatch = regex.search("[A-R]{2}[0-9]{2}", line)

        #if found gets the match
        if(gridSqMatch):
            gridSq = gridSqMatch.group()

        #currently only getting rows with reported gridsquare, will add other categories
        #RR73 just happens to be a signoff message and a grid square, it is way out of the way so
        #ignoring for now
        if (gridSq != "" and gridSq != "RR73"):
            tokens = line.split()
            timeString = tokens[0]
            dateTime = datetime.strptime(timeString, '%y%m%d_%H%M%S')
            logDF = logDF.append({'Callsign':match, 'GridSquare':gridSq, 'GridSubSquare':"",
                                  'Time': dateTime, 'Month': dateTime.month, 'Day':dateTime.day, 'Hour':dateTime.hour,
                                  'Db': int(tokens[4])}, ignore_index=True)
        

logDF.head() #displays
# Out:
#   Callsign GridSquare GridSubSquare                Time  Day    Db  Hour  \
# 0    AD5CQ       EL29               2023-04-07 18:26:30  7.0  18.0  18.0
# 1   WA6EZV       EM79               2023-04-07 18:26:45  7.0   3.0  18.0
# 2   WA6EZV       EM79               2023-04-07 18:27:15  7.0  -4.0  18.0
# 3   KG4LKY       EM87               2023-04-07 18:27:15  7.0  -7.0  18.0
# 4    AD5CQ       EL29               2023-04-07 18:28:15  7.0   9.0  18.0
#
#    Month
# 0    4.0
# 1    4.0
# 2    4.0
# 3    4.0
# 4    4.0

# %%
logDF.dtypes
# Out:
# Callsign                 object
# GridSquare               object
# GridSubSquare            object
# Time             datetime64[ns]
# Day                     float64
# Db                      float64
# Hour                    float64
# Month                   float64
# dtype: object

# %%
gridHitsDF = logDF.groupby(logDF.GridSquare)\
            .agg({'Callsign':'nunique', 'Db':'mean'})\
            .rename(columns={"Callsign": "Callsigns", "Db": "DbMean"})
                  
gridHitsDF = gridHitsDF.reset_index()

gridHitsDF[0:10]
# Out:
#   GridSquare  Callsigns     DbMean
# 0       AD13          1  -9.000000
# 1       AF50          1   0.000000
# 2       BG08          1  -2.500000
# 3       BK29          1 -14.714286
# 4       BL01          1 -13.000000
# 5       BL11          2 -15.000000
# 6       BN35          1 -11.000000
# 7       BO49          1  -2.200000
# 8       BP51          5  -9.446809
# 9       BP64          1  -6.428571

# %%
def addLatLonFromMaidenhead(df):
    latLon = maidenhead.to_location(df["GridSquare"])
    df["lat"] = latLon[0]
    df["lon"] = latLon[1]
    return df

gridHitsDF = gridHitsDF.apply(addLatLonFromMaidenhead, axis=1)

gridHitsDF.head()
# Out:
#   GridSquare  Callsigns     DbMean   lat    lon
# 0       AD13          1  -9.000000 -57.0 -178.0
# 1       AF50          1   0.000000 -40.0 -170.0
# 2       BG08          1  -2.500000 -22.0 -160.0
# 3       BK29          1 -14.714286  19.0 -156.0
# 4       BL01          1 -13.000000  21.0 -160.0

# %%
def AddSunriseSunsetData(gridSquareDataFrame):
    
    #next row
    try:
        locationSunData = suntime.Sun(gridSquareDataFrame["lat"], gridSquareDataFrame["lon"])
        gridSquareDataFrame["sunrise"] = locationSunData.get_local_sunrise_time()
        gridSquareDataFrame["sunset"] = locationSunData.get_local_sunset_time()
    except:
        gridSquareDataFrame["sunrise"] = "NA"
        gridSquareDataFrame["sunset"] = "NA"
    
    return gridSquareDataFrame


gridHitsDF = gridHitsDF.apply(AddSunriseSunsetData, axis=1)

# %%
gridHitsDF.head()
# Out:
#   GridSquare  Callsigns     DbMean   lat    lon                    sunrise  \
# 0       AD13          1  -9.000000 -57.0 -178.0  2023-04-17 11:52:00-07:00
# 1       AF50          1   0.000000 -40.0 -170.0  2023-04-17 10:51:00-07:00
# 2       BG08          1  -2.500000 -22.0 -160.0  2023-04-17 09:53:00-07:00
# 3       BK29          1 -14.714286  19.0 -156.0  2023-04-17 09:06:00-07:00
# 4       BL01          1 -13.000000  21.0 -160.0  2023-04-17 09:20:00-07:00
#
#                       sunset
# 0  2023-04-16 21:50:00-07:00
# 1  2023-04-16 21:47:00-07:00
# 2  2023-04-16 21:26:00-07:00
# 3  2023-04-16 21:42:00-07:00
# 4  2023-04-16 22:00:00-07:00

# %%
#merge back in
logDF = logDF.merge(gridHitsDF[["GridSquare", "sunrise", "sunset", "lat", "lon"]], how="left", on="GridSquare")

# %%
logDF.head()
# Out:
#   Callsign GridSquare GridSubSquare                Time  Day    Db  Hour  \
# 0    AD5CQ       EL29               2023-04-07 18:26:30  7.0  18.0  18.0
# 1   WA6EZV       EM79               2023-04-07 18:26:45  7.0   3.0  18.0
# 2   WA6EZV       EM79               2023-04-07 18:27:15  7.0  -4.0  18.0
# 3   KG4LKY       EM87               2023-04-07 18:27:15  7.0  -7.0  18.0
# 4    AD5CQ       EL29               2023-04-07 18:28:15  7.0   9.0  18.0
#
#    Month                    sunrise                     sunset   lat   lon
# 0    4.0  2023-04-17 04:56:00-07:00  2023-04-16 17:51:00-07:00  29.0 -96.0
# 1    4.0  2023-04-17 04:05:00-07:00  2023-04-16 17:23:00-07:00  39.0 -86.0
# 2    4.0  2023-04-17 04:05:00-07:00  2023-04-16 17:23:00-07:00  39.0 -86.0
# 3    4.0  2023-04-17 04:00:00-07:00  2023-04-16 17:12:00-07:00  37.0 -84.0
# 4    4.0  2023-04-17 04:56:00-07:00  2023-04-16 17:51:00-07:00  29.0 -96.0

# %%
test = list()

def buildGridSquareGeoJSON(df):
    test.append(df["GridSquare"])
    
gridHitsDF.apply(buildGridSquareGeoJSON, axis=1)
# Out:
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
#        ...
# 597    None
# 598    None
# 599    None
# 600    None
# 601    None
# Length: 602, dtype: object

# %%
test
# Out:
# ['AD13',
#  'AF50',
#  'BG08',
#  'BK29',
#  'BL01',
#  'BL11',
#  'BN35',
#  'BO49',
#  'BP51',
#  'BP64',
#  'BP74',
#  'CF23',
#  'CH01',
#  'CH42',
#  'CJ65',
#  'CM87',
#  'CM88',
#  'CM95',
#  'CM96',
#  'CM97',
#  'CM98',
#  'CM99',
#  'CN80',
#  'CN82',
#  'CN83',
#  'CN84',
#  'CN85',
#  'CN86',
#  'CN87',
#  'CN88',
#  'CN89',
#  'CN94',
#  'CN96',
#  'CN97',
#  'CN98',
#  'CR61',
#  'DL10',
#  'DL64',
#  'DL74',
#  'DL80',
#  'DL82',
#  'DL90',
#  'DL92',
#  'DL95',
#  'DL96',
#  'DM03',
#  'DM04',
#  'DM05',
#  'DM06',
#  'DM09',
#  'DM11',
#  'DM12',
#  'DM13',
#  'DM14',
#  'DM15',
#  'DM16',
#  'DM22',
#  'DM24',
#  'DM25',
#  'DM26',
#  'DM33',
#  'DM34',
#  'DM35',
#  'DM37',
#  'DM38',
#  'DM41',
#  'DM42',
#  'DM43',
#  'DM44',
#  'DM52',
#  'DM56',
#  'DM57',
#  'DM58',
#  'DM59',
#  'DM61',
#  'DM62',
#  'DM64',
#  'DM65',
#  'DM66',
#  'DM67',
#  'DM69',
#  'DM72',
#  'DM75',
#  'DM78',
#  'DM79',
#  'DM81',
#  'DM89',
#  'DM91',
#  'DM94',
#  'DM95',
#  'DM98',
#  'DN06',
#  'DN13',
#  'DN17',
#  'DN18',
#  'DN27',
#  'DN30',
#  'DN40',
#  'DN41',
#  'DN43',
#  'DN45',
#  'DN49',
#  'DN55',
#  'DN60',
#  'DN61',
#  'DN70',
#  'DN71',
#  'DN80',
#  'DN83',
#  'DN85',
#  'DN94',
#  'DN96',
#  'DN97',
#  'DN98',
#  'DO20',
#  'DO33',
#  'DO62',
#  'DO70',
#  'DO93',
#  'DP22',
#  'EJ79',
#  'EK09',
#  'EK62',
#  'EL06',
#  'EL09',
#  'EL15',
#  'EL16',
#  'EL17',
#  'EL18',
#  'EL19',
#  'EL28',
#  'EL29',
#  'EL39',
#  'EL49',
#  'EL79',
#  'EL82',
#  'EL83',
#  'EL86',
#  'EL87',
#  'EL88',
#  'EL89',
#  'EL91',
#  'EL94',
#  'EL95',
#  'EL96',
#  'EL97',
#  'EL98',
#  'EL99',
#  'EM00',
#  'EM02',
#  'EM04',
#  'EM08',
#  'EM09',
#  'EM10',
#  'EM11',
#  'EM12',
#  'EM13',
#  'EM14',
#  'EM15',
#  'EM16',
#  'EM17',
#  'EM19',
#  'EM20',
#  'EM21',
#  'EM22',
#  'EM23',
#  'EM25',
#  'EM26',
#  'EM28',
#  'EM29',
#  'EM30',
#  'EM31',
#  'EM32',
#  'EM34',
#  'EM35',
#  'EM36',
#  'EM37',
#  'EM38',
#  'EM40',
#  'EM41',
#  'EM42',
#  'EM43',
#  'EM44',
#  'EM45',
#  'EM46',
#  'EM47',
#  'EM48',
#  'EM49',
#  'EM50',
#  'EM51',
#  'EM52',
#  'EM53',
#  'EM54',
#  'EM55',
#  'EM56',
#  'EM57',
#  'EM58',
#  'EM59',
#  'EM60',
#  'EM62',
#  'EM63',
#  'EM64',
#  'EM65',
#  'EM66',
#  'EM67',
#  'EM68',
#  'EM69',
#  'EM70',
#  'EM71',
#  'EM73',
#  'EM74',
#  'EM75',
#  'EM76',
#  'EM77',
#  'EM78',
#  'EM79',
#  'EM80',
#  'EM81',
#  'EM82',
#  'EM83',
#  'EM84',
#  'EM85',
#  'EM86',
#  'EM87',
#  'EM88',
#  'EM89',
#  'EM90',
#  'EM91',
#  'EM92',
#  'EM93',
#  'EM94',
#  'EM95',
#  'EM96',
#  'EM97',
#  'EM98',
#  'EM99',
#  'EN03',
#  'EN04',
#  'EN05',
#  'EN06',
#  'EN08',
#  'EN09',
#  'EN10',
#  'EN11',
#  'EN12',
#  'EN13',
#  'EN14',
#  'EN16',
#  'EN19',
#  'EN21',
#  'EN23',
#  'EN25',
#  'EN26',
#  'EN27',
#  'EN29',
#  'EN31',
#  'EN32',
#  'EN33',
#  'EN34',
#  'EN35',
#  'EN36',
#  'EN37',
#  'EN40',
#  'EN41',
#  'EN42',
#  'EN43',
#  'EN44',
#  'EN47',
#  'EN50',
#  'EN51',
#  'EN52',
#  'EN53',
#  'EN54',
#  'EN55',
#  'EN56',
#  'EN57',
#  'EN58',
#  'EN60',
#  'EN61',
#  'EN62',
#  'EN63',
#  'EN64',
#  'EN65',
#  'EN66',
#  'EN70',
#  'EN71',
#  'EN72',
#  'EN73',
#  'EN74',
#  'EN76',
#  'EN80',
#  'EN81',
#  'EN82',
#  'EN83',
#  'EN84',
#  'EN90',
#  'EN91',
#  'EN92',
#  'EN93',
#  'EN94',
#  'EN96',
#  'EO20',
#  'EP23',
#  'FD66',
#  'FF31',
#  'FF33',
#  'FF46',
#  'FF51',
#  'FF57',
#  'FF78',
#  'FF81',
#  'FF94',
#  'FF97',
#  'FG42',
#  'FG46',
#  'FG92',
#  'FG93',
#  'FH17',
#  'FI07',
#  'FI09',
#  'FJ09',
#  'FJ13',
#  'FJ26',
#  'FK48',
#  'FK49',
#  'FK52',
#  'FK58',
#  'FK60',
#  'FK67',
#  'FK68',
#  'FK78',
#  'FK88',
#  'FK90',
#  'FK93',
#  'FL01',
#  'FL11',
#  'FL20',
#  'FM02',
#  'FM03',
#  'FM04',
#  'FM05',
#  'FM06',
#  'FM07',
#  'FM08',
#  'FM09',
#  'FM14',
#  'FM15',
#  'FM16',
#  'FM17',
#  'FM18',
#  'FM19',
#  'FM28',
#  'FM29',
#  'FN00',
#  'FN01',
#  'FN02',
#  'FN03',
#  'FN04',
#  'FN06',
#  'FN10',
#  'FN11',
#  'FN12',
#  'FN13',
#  'FN14',
#  'FN20',
#  'FN21',
#  'FN22',
#  'FN23',
#  'FN24',
#  'FN25',
#  'FN30',
#  'FN31',
#  'FN32',
#  'FN33',
#  'FN34',
#  'FN35',
#  'FN41',
#  'FN42',
#  'FN43',
#  'FN44',
#  'FN46',
#  'FN47',
#  'FN51',
#  'FN53',
#  'FN54',
#  'FN55',
#  'FN58',
#  'FN59',
#  'FN64',
#  'FN65',
#  'FN67',
#  'FN74',
#  'FN75',
#  'FN76',
#  'FN84',
#  'FN85',
#  'FN96',
#  'FO62',
#  'GF01',
#  'GF04',
#  'GF05',
#  'GF12',
#  'GF18',
#  'GG14',
#  'GG30',
#  'GG33',
#  'GG42',
#  'GG44',
#  'GG48',
#  'GG52',
#  'GG53',
#  'GG54',
#  'GG64',
#  'GG66',
#  'GG76',
#  'GG86',
#  'GG88',
#  'GH64',
#  'GR12',
#  'HF20',
#  'HI21',
#  'HK52',
#  'HM49',
#  'HM58',
#  'HM68',
#  'HM77',
#  'IC47',
#  'IE57',
#  'IL18',
#  'IL28',
#  'IM58',
#  'IM59',
#  'IM66',
#  'IM69',
#  'IM76',
#  'IM77',
#  'IM87',
#  'IM89',
#  'IM98',
#  'IM99',
#  'IN51',
#  'IN52',
#  'IN62',
#  'IN70',
#  'IN71',
#  'IN72',
#  'IN78',
#  'IN80',
#  'IN81',
#  'IN82',
#  'IN96',
#  'IO08',
#  'IO63',
#  'IO65',
#  'IO75',
#  'IO80',
#  'IO82',
#  'IO83',
#  'IO90',
#  'IO91',
#  'IO93',
#  'IO95',
#  'IP89',
#  'IQ25',
#  'IR33',
#  'JF77',
#  'JI64',
#  'JM13',
#  'JM78',
#  'JM88',
#  'JN00',
#  'JN01',
#  'JN04',
#  'JN08',
#  'JN11',
#  'JN19',
#  'JN39',
#  'JN45',
#  'JN48',
#  'JN59',
#  'JN62',
#  'JN63',
#  'JN65',
#  'JN66',
#  'JN68',
#  'JN70',
#  'JN71',
#  'JN75',
#  'JN92',
#  'JN95',
#  'JN99',
#  'JO02',
#  'JO11',
#  'JO20',
#  'JO21',
#  'JO22',
#  'JO30',
#  'JO31',
#  'JO33',
#  'JO41',
#  'JO48',
#  'JO53',
#  'JO54',
#  'JO70',
#  'JO76',
#  'JO90',
#  'JO93',
#  'JO94',
#  'KF16',
#  'KL95',
#  'KM17',
#  'KM46',
#  'KM65',
#  'KN04',
#  'KN10',
#  'KN22',
#  'KN27',
#  'KN28',
#  'KN32',
#  'KN34',
#  'KN35',
#  'KN58',
#  'KN65',
#  'KN77',
#  'KN84',
#  'KN89',
#  'KN93',
#  'KN94',
#  'KN96',
#  'KO05',
#  'KO25',
#  'KO50',
#  'KO59',
#  'KO61',
#  'KO80',
#  'KO84',
#  'KO85',
#  'KO90',
#  'KO92',
#  'KO95',
#  'KO99',
#  'KP20',
#  'KP24',
#  'KP69',
#  'LL39',
#  'LL55',
#  'LN03',
#  'LN05',
#  'LN07',
#  'LN13',
#  'LN32',
#  'LO01',
#  'LO02',
#  'LO13',
#  'LO21',
#  'LO32',
#  'LO43',
#  'LO64',
#  'LO81',
#  'LO89',
#  'LP51',
#  'MM28',
#  'MO05',
#  'MO09',
#  'MO16',
#  'MO25',
#  'MO27',
#  'MO28',
#  'MQ13',
#  'NI29',
#  'NO36',
#  'NO56',
#  'NO80',
#  'OI33',
#  'OM91',
#  'OO22',
#  'PF40',
#  'PI19',
#  'PM37',
#  'PM52',
#  'PM53',
#  'PM74',
#  'PM85',
#  'PM86',
#  'PM94',
#  'PM95',
#  'PM96',
#  'PM97',
#  'PN64',
#  'QM05',
#  'QM06',
#  'QM07',
#  'QM08',
#  'QM09',
#  'QN03',
#  'QN13',
#  'QO59',
#  'RF72',
#  'RI27',
#  'RM26',
#  'RP34',
#  'RR01']

# %%
#VISUALIZATION OF DECODED GRIDSQUARES
def get_polygon(lon, lat, id):
    
    coords = [[lon-gridWidthInLong/2, lat-gridHeightInLat/2], [lon+gridWidthInLong/2, lat-gridHeightInLat/2], [lon+gridWidthInLong/2, lat+gridHeightInLat/2], [lon-gridWidthInLong/2, lat+gridHeightInLat/2]]
    
    return { "type": "Feature",
                               "geometry": {"type": "Polygon",
                                            "coordinates": [coords]}, "id":id}


geojd = {"type": "FeatureCollection"}
geojd['features'] = []


#grid station map geojson
def buildGridSquareGeoJSON(df):
    geojd['features'].append(get_polygon(lon=df["lon"], lat=df["lat"], id=df["GridSquare"]))
    
gridHitsDF.apply(buildGridSquareGeoJSON, axis=1)
    


fig = px.choropleth_mapbox(gridHitsDF,geojson=geojd,locations="GridSquare",color="DbMean",
                           color_continuous_scale="Viridis",
                           range_color=(-25, 25),
                           mapbox_style="carto-positron",
                           zoom=1, center = {"lat": 80, "lon": -77},
                           opacity=0.5,
                           labels={'ID':'Grid Square'}
                          )


fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()

# %%
geojd
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-179.0, -57.5],
#       [-177.0, -57.5],
#       [-177.0, -56.5],
#       [-179.0, -56.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-171.0, -40.5],
#       [-169.0, -40.5],
#       [-169.0, -39.5],
#       [-171.0, -39.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-161.0, -22.5],
#       [-159.0, -22.5],
#       [-159.0, -21.5],
#       [-161.0, -21.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-157.0, 18.5],
#       [-155.0, 18.5],
#       [-155.0, 19.5],
#       [-157.0, 19.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-161.0, 20.5],
#       [-159.0, 20.5],
#       [-159.0, 21.5],
#       [-161.0, 21.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-159.0, 20.5],
#       [-157.0, 20.5],
#       [-157.0, 21.5],
#       [-159.0, 21.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-155.0, 44.5],
#       [-153.0, 44.5],
#       [-153.0, 45.5],
#       [-155.0, 45.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-153.0, 58.5],
#       [-151.0, 58.5],
#       [-151.0, 59.5],
#       [-153.0, 59.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-151.0, 60.5],
#       [-149.0, 60.5],
#       [-149.0, 61.5],
#       [-151.0, 61.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-149.0, 63.5],
#       [-147.0, 63.5],
#       [-147.0, 64.5],
#       [-149.0, 64.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-147.0, 63.5],
#       [-145.0, 63.5],
#       [-145.0, 64.5],
#       [-147.0, 64.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-137.0, -37.5],
#       [-135.0, -37.5],
#       [-135.0, -36.5],
#       [-137.0, -36.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-141.0, -19.5],
#       [-139.0, -19.5],
#       [-139.0, -18.5],
#       [-141.0, -18.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-133.0, -18.5],
#       [-131.0, -18.5],
#       [-131.0, -17.5],
#       [-133.0, -17.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-129.0, 4.5],
#       [-127.0, 4.5],
#       [-127.0, 5.5],
#       [-129.0, 5.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-125.0, 36.5],
#       [-123.0, 36.5],
#       [-123.0, 37.5],
#       [-125.0, 37.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-125.0, 37.5],
#       [-123.0, 37.5],
#       [-123.0, 38.5],
#       [-125.0, 38.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-123.0, 34.5],
#       [-121.0, 34.5],
#       [-121.0, 35.5],
#       [-123.0, 35.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-123.0, 35.5],
#       [-121.0, 35.5],
#       [-121.0, 36.5],
#       [-123.0, 36.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-123.0, 36.5],
#       [-121.0, 36.5],
#       [-121.0, 37.5],
#       [-123.0, 37.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-123.0, 37.5],
#       [-121.0, 37.5],
#       [-121.0, 38.5],
#       [-123.0, 38.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-123.0, 38.5],
#       [-121.0, 38.5],
#       [-121.0, 39.5],
#       [-123.0, 39.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-125.0, 39.5],
#       [-123.0, 39.5],
#       [-123.0, 40.5],
#       [-125.0, 40.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-125.0, 41.5],
#       [-123.0, 41.5],
#       [-123.0, 42.5],
#       [-125.0, 42.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-125.0, 42.5],
#       [-123.0, 42.5],
#       [-123.0, 43.5],
#       [-125.0, 43.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-125.0, 43.5],
#       [-123.0, 43.5],
#       [-123.0, 44.5],
#       [-125.0, 44.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-125.0, 44.5],
#       [-123.0, 44.5],
#       [-123.0, 45.5],
#       [-125.0, 45.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-125.0, 45.5],
#       [-123.0, 45.5],
#       [-123.0, 46.5],
#       [-125.0, 46.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-125.0, 46.5],
#       [-123.0, 46.5],
#       [-123.0, 47.5],
#       [-125.0, 47.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-125.0, 47.5],
#       [-123.0, 47.5],
#       [-123.0, 48.5],
#       [-125.0, 48.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-125.0, 48.5],
#       [-123.0, 48.5],
#       [-123.0, 49.5],
#       [-125.0, 49.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-123.0, 43.5],
#       [-121.0, 43.5],
#       [-121.0, 44.5],
#       [-123.0, 44.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-123.0, 45.5],
#       [-121.0, 45.5],
#       [-121.0, 46.5],
#       [-123.0, 46.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-123.0, 46.5],
#       [-121.0, 46.5],
#       [-121.0, 47.5],
#       [-123.0, 47.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-123.0, 47.5],
#       [-121.0, 47.5],
#       [-121.0, 48.5],
#       [-123.0, 48.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-129.0, 80.5],
#       [-127.0, 80.5],
#       [-127.0, 81.5],
#       [-129.0, 81.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-119.0, 19.5],
#       [-117.0, 19.5],
#       [-117.0, 20.5],
#       [-119.0, 20.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-109.0, 23.5],
#       [-107.0, 23.5],
#       [-107.0, 24.5],
#       [-109.0, 24.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-107.0, 23.5],
#       [-105.0, 23.5],
#       [-105.0, 24.5],
#       [-107.0, 24.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-105.0, 19.5],
#       [-103.0, 19.5],
#       [-103.0, 20.5],
#       [-105.0, 20.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-105.0, 21.5],
#       [-103.0, 21.5],
#       [-103.0, 22.5],
#       [-105.0, 22.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-103.0, 19.5],
#       [-101.0, 19.5],
#       [-101.0, 20.5],
#       [-103.0, 20.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-103.0, 21.5],
#       [-101.0, 21.5],
#       [-101.0, 22.5],
#       [-103.0, 22.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-103.0, 24.5],
#       [-101.0, 24.5],
#       [-101.0, 25.5],
#       [-103.0, 25.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-103.0, 25.5],
#       [-101.0, 25.5],
#       [-101.0, 26.5],
#       [-103.0, 26.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-121.0, 32.5],
#       [-119.0, 32.5],
#       [-119.0, 33.5],
#       [-121.0, 33.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-121.0, 33.5],
#       [-119.0, 33.5],
#       [-119.0, 34.5],
#       [-121.0, 34.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-121.0, 34.5],
#       [-119.0, 34.5],
#       [-119.0, 35.5],
#       [-121.0, 35.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-121.0, 35.5],
#       [-119.0, 35.5],
#       [-119.0, 36.5],
#       [-121.0, 36.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-121.0, 38.5],
#       [-119.0, 38.5],
#       [-119.0, 39.5],
#       [-121.0, 39.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-119.0, 30.5],
#       [-117.0, 30.5],
#       [-117.0, 31.5],
#       [-119.0, 31.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-119.0, 31.5],
#       [-117.0, 31.5],
#       [-117.0, 32.5],
#       [-119.0, 32.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-119.0, 32.5],
#       [-117.0, 32.5],
#       [-117.0, 33.5],
#       [-119.0, 33.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-119.0, 33.5],
#       [-117.0, 33.5],
#       [-117.0, 34.5],
#       [-119.0, 34.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-119.0, 34.5],
#       [-117.0, 34.5],
#       [-117.0, 35.5],
#       [-119.0, 35.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-119.0, 35.5],
#       [-117.0, 35.5],
#       [-117.0, 36.5],
#       [-119.0, 36.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-117.0, 31.5],
#       [-115.0, 31.5],
#       [-115.0, 32.5],
#       [-117.0, 32.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-117.0, 33.5],
#       [-115.0, 33.5],
#       [-115.0, 34.5],
#       [-117.0, 34.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-117.0, 34.5],
#       [-115.0, 34.5],
#       [-115.0, 35.5],
#       [-117.0, 35.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-117.0, 35.5],
#       [-115.0, 35.5],
#       [-115.0, 36.5],
#       [-117.0, 36.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-115.0, 32.5],
#       [-113.0, 32.5],
#       [-113.0, 33.5],
#       [-115.0, 33.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-115.0, 33.5],
#       [-113.0, 33.5],
#       [-113.0, 34.5],
#       [-115.0, 34.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-115.0, 34.5],
#       [-113.0, 34.5],
#       [-113.0, 35.5],
#       [-115.0, 35.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-115.0, 36.5],
#       [-113.0, 36.5],
#       [-113.0, 37.5],
#       [-115.0, 37.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-115.0, 37.5],
#       [-113.0, 37.5],
#       [-113.0, 38.5],
#       [-115.0, 38.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-113.0, 30.5],
#       [-111.0, 30.5],
#       [-111.0, 31.5],
#       [-113.0, 31.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-113.0, 31.5],
#       [-111.0, 31.5],
#       [-111.0, 32.5],
#       [-113.0, 32.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-113.0, 32.5],
#       [-111.0, 32.5],
#       [-111.0, 33.5],
#       [-113.0, 33.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-113.0, 33.5],
#       [-111.0, 33.5],
#       [-111.0, 34.5],
#       [-113.0, 34.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-111.0, 31.5],
#       [-109.0, 31.5],
#       [-109.0, 32.5],
#       [-111.0, 32.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-111.0, 35.5],
#       [-109.0, 35.5],
#       [-109.0, 36.5],
#       [-111.0, 36.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-111.0, 36.5],
#       [-109.0, 36.5],
#       [-109.0, 37.5],
#       [-111.0, 37.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-111.0, 37.5],
#       [-109.0, 37.5],
#       [-109.0, 38.5],
#       [-111.0, 38.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-111.0, 38.5],
#       [-109.0, 38.5],
#       [-109.0, 39.5],
#       [-111.0, 39.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-109.0, 30.5],
#       [-107.0, 30.5],
#       [-107.0, 31.5],
#       [-109.0, 31.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-109.0, 31.5],
#       [-107.0, 31.5],
#       [-107.0, 32.5],
#       [-109.0, 32.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-109.0, 33.5],
#       [-107.0, 33.5],
#       [-107.0, 34.5],
#       [-109.0, 34.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-109.0, 34.5],
#       [-107.0, 34.5],
#       [-107.0, 35.5],
#       [-109.0, 35.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-109.0, 35.5],
#       [-107.0, 35.5],
#       [-107.0, 36.5],
#       [-109.0, 36.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-109.0, 36.5],
#       [-107.0, 36.5],
#       [-107.0, 37.5],
#       [-109.0, 37.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-109.0, 38.5],
#       [-107.0, 38.5],
#       [-107.0, 39.5],
#       [-109.0, 39.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-107.0, 31.5],
#       [-105.0, 31.5],
#       [-105.0, 32.5],
#       [-107.0, 32.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-107.0, 34.5],
#       [-105.0, 34.5],
#       [-105.0, 35.5],
#       [-107.0, 35.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-107.0, 37.5],
#       [-105.0, 37.5],
#       [-105.0, 38.5],
#       [-107.0, 38.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-107.0, 38.5],
#       [-105.0, 38.5],
#       [-105.0, 39.5],
#       [-107.0, 39.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-105.0, 30.5],
#       [-103.0, 30.5],
#       [-103.0, 31.5],
#       [-105.0, 31.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-105.0, 38.5],
#       [-103.0, 38.5],
#       [-103.0, 39.5],
#       [-105.0, 39.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-103.0, 30.5],
#       [-101.0, 30.5],
#       [-101.0, 31.5],
#       [-103.0, 31.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-103.0, 33.5],
#       [-101.0, 33.5],
#       [-101.0, 34.5],
#       [-103.0, 34.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-103.0, 34.5],
#       [-101.0, 34.5],
#       [-101.0, 35.5],
#       [-103.0, 35.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-103.0, 37.5],
#       [-101.0, 37.5],
#       [-101.0, 38.5],
#       [-103.0, 38.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-121.0, 45.5],
#       [-119.0, 45.5],
#       [-119.0, 46.5],
#       [-121.0, 46.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-119.0, 42.5],
#       [-117.0, 42.5],
#       [-117.0, 43.5],
#       [-119.0, 43.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-119.0, 46.5],
#       [-117.0, 46.5],
#       [-117.0, 47.5],
#       [-119.0, 47.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-119.0, 47.5],
#       [-117.0, 47.5],
#       [-117.0, 48.5],
#       [-119.0, 48.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-117.0, 46.5],
#       [-115.0, 46.5],
#       [-115.0, 47.5],
#       [-117.0, 47.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-115.0, 39.5],
#       [-113.0, 39.5],
#       [-113.0, 40.5],
#       [-115.0, 40.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-113.0, 39.5],
#       [-111.0, 39.5],
#       [-111.0, 40.5],
#       [-113.0, 40.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-113.0, 40.5],
#       [-111.0, 40.5],
#       [-111.0, 41.5],
#       [-113.0, 41.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-113.0, 42.5],
#       [-111.0, 42.5],
#       [-111.0, 43.5],
#       [-113.0, 43.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-113.0, 44.5],
#       [-111.0, 44.5],
#       [-111.0, 45.5],
#       [-113.0, 45.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-113.0, 48.5],
#       [-111.0, 48.5],
#       [-111.0, 49.5],
#       [-113.0, 49.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-111.0, 44.5],
#       [-109.0, 44.5],
#       [-109.0, 45.5],
#       [-111.0, 45.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-109.0, 39.5],
#       [-107.0, 39.5],
#       [-107.0, 40.5],
#       [-109.0, 40.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-109.0, 40.5],
#       [-107.0, 40.5],
#       [-107.0, 41.5],
#       [-109.0, 41.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-107.0, 39.5],
#       [-105.0, 39.5],
#       [-105.0, 40.5],
#       [-107.0, 40.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-107.0, 40.5],
#       [-105.0, 40.5],
#       [-105.0, 41.5],
#       [-107.0, 41.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-105.0, 39.5],
#       [-103.0, 39.5],
#       [-103.0, 40.5],
#       [-105.0, 40.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-105.0, 42.5],
#       [-103.0, 42.5],
#       [-103.0, 43.5],
#       [-105.0, 43.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-105.0, 44.5],
#       [-103.0, 44.5],
#       [-103.0, 45.5],
#       [-105.0, 45.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-103.0, 43.5],
#       [-101.0, 43.5],
#       [-101.0, 44.5],
#       [-103.0, 44.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-103.0, 45.5],
#       [-101.0, 45.5],
#       [-101.0, 46.5],
#       [-103.0, 46.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-103.0, 46.5],
#       [-101.0, 46.5],
#       [-101.0, 47.5],
#       [-103.0, 47.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-103.0, 47.5],
#       [-101.0, 47.5],
#       [-101.0, 48.5],
#       [-103.0, 48.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-117.0, 49.5],
#       [-115.0, 49.5],
#       [-115.0, 50.5],
#       [-117.0, 50.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-115.0, 52.5],
#       [-113.0, 52.5],
#       [-113.0, 53.5],
#       [-115.0, 53.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-109.0, 51.5],
#       [-107.0, 51.5],
#       [-107.0, 52.5],
#       [-109.0, 52.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-107.0, 49.5],
#       [-105.0, 49.5],
#       [-105.0, 50.5],
#       [-107.0, 50.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-103.0, 52.5],
#       [-101.0, 52.5],
#       [-101.0, 53.5],
#       [-103.0, 53.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-117.0, 61.5],
#       [-115.0, 61.5],
#       [-115.0, 62.5],
#       [-117.0, 62.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-87.0, 8.5], [-85.0, 8.5], [-85.0, 9.5], [-87.0, 9.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-101.0, 18.5],
#       [-99.0, 18.5],
#       [-99.0, 19.5],
#       [-101.0, 19.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-89.0, 11.5],
#       [-87.0, 11.5],
#       [-87.0, 12.5],
#       [-89.0, 12.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-101.0, 25.5],
#       [-99.0, 25.5],
#       [-99.0, 26.5],
#       [-101.0, 26.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-101.0, 28.5],
#       [-99.0, 28.5],
#       [-99.0, 29.5],
#       [-101.0, 29.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-99.0, 24.5],
#       [-97.0, 24.5],
#       [-97.0, 25.5],
#       [-99.0, 25.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-99.0, 25.5],
#       [-97.0, 25.5],
#       [-97.0, 26.5],
#       [-99.0, 26.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-99.0, 26.5],
#       [-97.0, 26.5],
#       [-97.0, 27.5],
#       [-99.0, 27.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-99.0, 27.5],
#       [-97.0, 27.5],
#       [-97.0, 28.5],
#       [-99.0, 28.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-99.0, 28.5],
#       [-97.0, 28.5],
#       [-97.0, 29.5],
#       [-99.0, 29.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-97.0, 27.5],
#       [-95.0, 27.5],
#       [-95.0, 28.5],
#       [-97.0, 28.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-97.0, 28.5],
#       [-95.0, 28.5],
#       [-95.0, 29.5],
#       [-97.0, 29.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-95.0, 28.5],
#       [-93.0, 28.5],
#       [-93.0, 29.5],
#       [-95.0, 29.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-93.0, 28.5],
#       [-91.0, 28.5],
#       [-91.0, 29.5],
#       [-93.0, 29.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-87.0, 28.5],
#       [-85.0, 28.5],
#       [-85.0, 29.5],
#       [-87.0, 29.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-85.0, 21.5],
#       [-83.0, 21.5],
#       [-83.0, 22.5],
#       [-85.0, 22.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-85.0, 22.5],
#       [-83.0, 22.5],
#       [-83.0, 23.5],
#       [-85.0, 23.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-85.0, 25.5],
#       [-83.0, 25.5],
#       [-83.0, 26.5],
#       [-85.0, 26.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-85.0, 26.5],
#       [-83.0, 26.5],
#       [-83.0, 27.5],
#       [-85.0, 27.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-85.0, 27.5],
#       [-83.0, 27.5],
#       [-83.0, 28.5],
#       [-85.0, 28.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-85.0, 28.5],
#       [-83.0, 28.5],
#       [-83.0, 29.5],
#       [-85.0, 29.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-83.0, 20.5],
#       [-81.0, 20.5],
#       [-81.0, 21.5],
#       [-83.0, 21.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-83.0, 23.5],
#       [-81.0, 23.5],
#       [-81.0, 24.5],
#       [-83.0, 24.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-83.0, 24.5],
#       [-81.0, 24.5],
#       [-81.0, 25.5],
#       [-83.0, 25.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-83.0, 25.5],
#       [-81.0, 25.5],
#       [-81.0, 26.5],
#       [-83.0, 26.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-83.0, 26.5],
#       [-81.0, 26.5],
#       [-81.0, 27.5],
#       [-83.0, 27.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-83.0, 27.5],
#       [-81.0, 27.5],
#       [-81.0, 28.5],
#       [-83.0, 28.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-83.0, 28.5],
#       [-81.0, 28.5],
#       [-81.0, 29.5],
#       [-83.0, 29.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-101.0, 29.5],
#       [-99.0, 29.5],
#       [-99.0, 30.5],
#       [-101.0, 30.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-101.0, 31.5],
#       [-99.0, 31.5],
#       [-99.0, 32.5],
#       [-101.0, 32.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-101.0, 33.5],
#       [-99.0, 33.5],
#       [-99.0, 34.5],
#       [-101.0, 34.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-101.0, 37.5],
#       [-99.0, 37.5],
#       [-99.0, 38.5],
#       [-101.0, 38.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-101.0, 38.5],
#       [-99.0, 38.5],
#       [-99.0, 39.5],
#       [-101.0, 39.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-99.0, 29.5],
#       [-97.0, 29.5],
#       [-97.0, 30.5],
#       [-99.0, 30.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-99.0, 30.5],
#       [-97.0, 30.5],
#       [-97.0, 31.5],
#       [-99.0, 31.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-99.0, 31.5],
#       [-97.0, 31.5],
#       [-97.0, 32.5],
#       [-99.0, 32.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-99.0, 32.5],
#       [-97.0, 32.5],
#       [-97.0, 33.5],
#       [-99.0, 33.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-99.0, 33.5],
#       [-97.0, 33.5],
#       [-97.0, 34.5],
#       [-99.0, 34.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-99.0, 34.5],
#       [-97.0, 34.5],
#       [-97.0, 35.5],
#       [-99.0, 35.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-99.0, 35.5],
#       [-97.0, 35.5],
#       [-97.0, 36.5],
#       [-99.0, 36.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-99.0, 36.5],
#       [-97.0, 36.5],
#       [-97.0, 37.5],
#       [-99.0, 37.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-99.0, 38.5],
#       [-97.0, 38.5],
#       [-97.0, 39.5],
#       [-99.0, 39.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-97.0, 29.5],
#       [-95.0, 29.5],
#       [-95.0, 30.5],
#       [-97.0, 30.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-97.0, 30.5],
#       [-95.0, 30.5],
#       [-95.0, 31.5],
#       [-97.0, 31.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-97.0, 31.5],
#       [-95.0, 31.5],
#       [-95.0, 32.5],
#       [-97.0, 32.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-97.0, 32.5],
#       [-95.0, 32.5],
#       [-95.0, 33.5],
#       [-97.0, 33.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-97.0, 34.5],
#       [-95.0, 34.5],
#       [-95.0, 35.5],
#       [-97.0, 35.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-97.0, 35.5],
#       [-95.0, 35.5],
#       [-95.0, 36.5],
#       [-97.0, 36.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-97.0, 37.5],
#       [-95.0, 37.5],
#       [-95.0, 38.5],
#       [-97.0, 38.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-97.0, 38.5],
#       [-95.0, 38.5],
#       [-95.0, 39.5],
#       [-97.0, 39.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-95.0, 29.5],
#       [-93.0, 29.5],
#       [-93.0, 30.5],
#       [-95.0, 30.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-95.0, 30.5],
#       [-93.0, 30.5],
#       [-93.0, 31.5],
#       [-95.0, 31.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-95.0, 31.5],
#       [-93.0, 31.5],
#       [-93.0, 32.5],
#       [-95.0, 32.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-95.0, 33.5],
#       [-93.0, 33.5],
#       [-93.0, 34.5],
#       [-95.0, 34.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-95.0, 34.5],
#       [-93.0, 34.5],
#       [-93.0, 35.5],
#       [-95.0, 35.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-95.0, 35.5],
#       [-93.0, 35.5],
#       [-93.0, 36.5],
#       [-95.0, 36.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-95.0, 36.5],
#       [-93.0, 36.5],
#       [-93.0, 37.5],
#       [-95.0, 37.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-95.0, 37.5],
#       [-93.0, 37.5],
#       [-93.0, 38.5],
#       [-95.0, 38.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-93.0, 29.5],
#       [-91.0, 29.5],
#       [-91.0, 30.5],
#       [-93.0, 30.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-93.0, 30.5],
#       [-91.0, 30.5],
#       [-91.0, 31.5],
#       [-93.0, 31.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-93.0, 31.5],
#       [-91.0, 31.5],
#       [-91.0, 32.5],
#       [-93.0, 32.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-93.0, 32.5],
#       [-91.0, 32.5],
#       [-91.0, 33.5],
#       [-93.0, 33.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-93.0, 33.5],
#       [-91.0, 33.5],
#       [-91.0, 34.5],
#       [-93.0, 34.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-93.0, 34.5],
#       [-91.0, 34.5],
#       [-91.0, 35.5],
#       [-93.0, 35.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-93.0, 35.5],
#       [-91.0, 35.5],
#       [-91.0, 36.5],
#       [-93.0, 36.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-93.0, 36.5],
#       [-91.0, 36.5],
#       [-91.0, 37.5],
#       [-93.0, 37.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-93.0, 37.5],
#       [-91.0, 37.5],
#       [-91.0, 38.5],
#       [-93.0, 38.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-93.0, 38.5],
#       [-91.0, 38.5],
#       [-91.0, 39.5],
#       [-93.0, 39.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-91.0, 29.5],
#       [-89.0, 29.5],
#       [-89.0, 30.5],
#       [-91.0, 30.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-91.0, 30.5],
#       [-89.0, 30.5],
#       [-89.0, 31.5],
#       [-91.0, 31.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-91.0, 31.5],
#       [-89.0, 31.5],
#       [-89.0, 32.5],
#       [-91.0, 32.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-91.0, 32.5],
#       [-89.0, 32.5],
#       [-89.0, 33.5],
#       [-91.0, 33.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-91.0, 33.5],
#       [-89.0, 33.5],
#       [-89.0, 34.5],
#       [-91.0, 34.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-91.0, 34.5],
#       [-89.0, 34.5],
#       [-89.0, 35.5],
#       [-91.0, 35.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-91.0, 35.5],
#       [-89.0, 35.5],
#       [-89.0, 36.5],
#       [-91.0, 36.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-91.0, 36.5],
#       [-89.0, 36.5],
#       [-89.0, 37.5],
#       [-91.0, 37.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-91.0, 37.5],
#       [-89.0, 37.5],
#       [-89.0, 38.5],
#       [-91.0, 38.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-91.0, 38.5],
#       [-89.0, 38.5],
#       [-89.0, 39.5],
#       [-91.0, 39.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-89.0, 29.5],
#       [-87.0, 29.5],
#       [-87.0, 30.5],
#       [-89.0, 30.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-89.0, 31.5],
#       [-87.0, 31.5],
#       [-87.0, 32.5],
#       [-89.0, 32.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-89.0, 32.5],
#       [-87.0, 32.5],
#       [-87.0, 33.5],
#       [-89.0, 33.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-89.0, 33.5],
#       [-87.0, 33.5],
#       [-87.0, 34.5],
#       [-89.0, 34.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-89.0, 34.5],
#       [-87.0, 34.5],
#       [-87.0, 35.5],
#       [-89.0, 35.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-89.0, 35.5],
#       [-87.0, 35.5],
#       [-87.0, 36.5],
#       [-89.0, 36.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-89.0, 36.5],
#       [-87.0, 36.5],
#       [-87.0, 37.5],
#       [-89.0, 37.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-89.0, 37.5],
#       [-87.0, 37.5],
#       [-87.0, 38.5],
#       [-89.0, 38.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-89.0, 38.5],
#       [-87.0, 38.5],
#       [-87.0, 39.5],
#       [-89.0, 39.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-87.0, 29.5],
#       [-85.0, 29.5],
#       [-85.0, 30.5],
#       [-87.0, 30.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-87.0, 30.5],
#       [-85.0, 30.5],
#       [-85.0, 31.5],
#       [-87.0, 31.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-87.0, 32.5],
#       [-85.0, 32.5],
#       [-85.0, 33.5],
#       [-87.0, 33.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-87.0, 33.5],
#       [-85.0, 33.5],
#       [-85.0, 34.5],
#       [-87.0, 34.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-87.0, 34.5],
#       [-85.0, 34.5],
#       [-85.0, 35.5],
#       [-87.0, 35.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-87.0, 35.5],
#       [-85.0, 35.5],
#       [-85.0, 36.5],
#       [-87.0, 36.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-87.0, 36.5],
#       [-85.0, 36.5],
#       [-85.0, 37.5],
#       [-87.0, 37.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-87.0, 37.5],
#       [-85.0, 37.5],
#       [-85.0, 38.5],
#       [-87.0, 38.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-87.0, 38.5],
#       [-85.0, 38.5],
#       [-85.0, 39.5],
#       [-87.0, 39.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-85.0, 29.5],
#       [-83.0, 29.5],
#       [-83.0, 30.5],
#       [-85.0, 30.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-85.0, 30.5],
#       [-83.0, 30.5],
#       [-83.0, 31.5],
#       [-85.0, 31.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-85.0, 31.5],
#       [-83.0, 31.5],
#       [-83.0, 32.5],
#       [-85.0, 32.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-85.0, 32.5],
#       [-83.0, 32.5],
#       [-83.0, 33.5],
#       [-85.0, 33.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-85.0, 33.5],
#       [-83.0, 33.5],
#       [-83.0, 34.5],
#       [-85.0, 34.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-85.0, 34.5],
#       [-83.0, 34.5],
#       [-83.0, 35.5],
#       [-85.0, 35.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-85.0, 35.5],
#       [-83.0, 35.5],
#       [-83.0, 36.5],
#       [-85.0, 36.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-85.0, 36.5],
#       [-83.0, 36.5],
#       [-83.0, 37.5],
#       [-85.0, 37.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-85.0, 37.5],
#       [-83.0, 37.5],
#       [-83.0, 38.5],
#       [-85.0, 38.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-85.0, 38.5],
#       [-83.0, 38.5],
#       [-83.0, 39.5],
#       [-85.0, 39.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-83.0, 29.5],
#       [-81.0, 29.5],
#       [-81.0, 30.5],
#       [-83.0, 30.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-83.0, 30.5],
#       [-81.0, 30.5],
#       [-81.0, 31.5],
#       [-83.0, 31.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-83.0, 31.5],
#       [-81.0, 31.5],
#       [-81.0, 32.5],
#       [-83.0, 32.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-83.0, 32.5],
#       [-81.0, 32.5],
#       [-81.0, 33.5],
#       [-83.0, 33.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-83.0, 33.5],
#       [-81.0, 33.5],
#       [-81.0, 34.5],
#       [-83.0, 34.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-83.0, 34.5],
#       [-81.0, 34.5],
#       [-81.0, 35.5],
#       [-83.0, 35.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-83.0, 35.5],
#       [-81.0, 35.5],
#       [-81.0, 36.5],
#       [-83.0, 36.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-83.0, 36.5],
#       [-81.0, 36.5],
#       [-81.0, 37.5],
#       [-83.0, 37.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-83.0, 37.5],
#       [-81.0, 37.5],
#       [-81.0, 38.5],
#       [-83.0, 38.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-83.0, 38.5],
#       [-81.0, 38.5],
#       [-81.0, 39.5],
#       [-83.0, 39.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-101.0, 42.5],
#       [-99.0, 42.5],
#       [-99.0, 43.5],
#       [-101.0, 43.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-101.0, 43.5],
#       [-99.0, 43.5],
#       [-99.0, 44.5],
#       [-101.0, 44.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-101.0, 44.5],
#       [-99.0, 44.5],
#       [-99.0, 45.5],
#       [-101.0, 45.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-101.0, 45.5],
#       [-99.0, 45.5],
#       [-99.0, 46.5],
#       [-101.0, 46.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-101.0, 47.5],
#       [-99.0, 47.5],
#       [-99.0, 48.5],
#       [-101.0, 48.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-101.0, 48.5],
#       [-99.0, 48.5],
#       [-99.0, 49.5],
#       [-101.0, 49.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-99.0, 39.5],
#       [-97.0, 39.5],
#       [-97.0, 40.5],
#       [-99.0, 40.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-99.0, 40.5],
#       [-97.0, 40.5],
#       [-97.0, 41.5],
#       [-99.0, 41.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-99.0, 41.5],
#       [-97.0, 41.5],
#       [-97.0, 42.5],
#       [-99.0, 42.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-99.0, 42.5],
#       [-97.0, 42.5],
#       [-97.0, 43.5],
#       [-99.0, 43.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-99.0, 43.5],
#       [-97.0, 43.5],
#       [-97.0, 44.5],
#       [-99.0, 44.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-99.0, 45.5],
#       [-97.0, 45.5],
#       [-97.0, 46.5],
#       [-99.0, 46.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-99.0, 48.5],
#       [-97.0, 48.5],
#       [-97.0, 49.5],
#       [-99.0, 49.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-97.0, 40.5],
#       [-95.0, 40.5],
#       [-95.0, 41.5],
#       [-97.0, 41.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-97.0, 42.5],
#       [-95.0, 42.5],
#       [-95.0, 43.5],
#       [-97.0, 43.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-97.0, 44.5],
#       [-95.0, 44.5],
#       [-95.0, 45.5],
#       [-97.0, 45.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-97.0, 45.5],
#       [-95.0, 45.5],
#       [-95.0, 46.5],
#       [-97.0, 46.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-97.0, 46.5],
#       [-95.0, 46.5],
#       [-95.0, 47.5],
#       [-97.0, 47.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-97.0, 48.5],
#       [-95.0, 48.5],
#       [-95.0, 49.5],
#       [-97.0, 49.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-95.0, 40.5],
#       [-93.0, 40.5],
#       [-93.0, 41.5],
#       [-95.0, 41.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-95.0, 41.5],
#       [-93.0, 41.5],
#       [-93.0, 42.5],
#       [-95.0, 42.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-95.0, 42.5],
#       [-93.0, 42.5],
#       [-93.0, 43.5],
#       [-95.0, 43.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-95.0, 43.5],
#       [-93.0, 43.5],
#       [-93.0, 44.5],
#       [-95.0, 44.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-95.0, 44.5],
#       [-93.0, 44.5],
#       [-93.0, 45.5],
#       [-95.0, 45.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-95.0, 45.5],
#       [-93.0, 45.5],
#       [-93.0, 46.5],
#       [-95.0, 46.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-95.0, 46.5],
#       [-93.0, 46.5],
#       [-93.0, 47.5],
#       [-95.0, 47.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-93.0, 39.5],
#       [-91.0, 39.5],
#       [-91.0, 40.5],
#       [-93.0, 40.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-93.0, 40.5],
#       [-91.0, 40.5],
#       [-91.0, 41.5],
#       [-93.0, 41.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-93.0, 41.5],
#       [-91.0, 41.5],
#       [-91.0, 42.5],
#       [-93.0, 42.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-93.0, 42.5],
#       [-91.0, 42.5],
#       [-91.0, 43.5],
#       [-93.0, 43.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-93.0, 43.5],
#       [-91.0, 43.5],
#       [-91.0, 44.5],
#       [-93.0, 44.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-93.0, 46.5],
#       [-91.0, 46.5],
#       [-91.0, 47.5],
#       [-93.0, 47.5]]]},
#    'id': 'RR01'},
# ...
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[13.0, 49.5], [15.0, 49.5], [15.0, 50.5], [13.0, 50.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[13.0, 55.5], [15.0, 55.5], [15.0, 56.5], [13.0, 56.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[17.0, 49.5], [19.0, 49.5], [19.0, 50.5], [17.0, 50.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[17.0, 52.5], [19.0, 52.5], [19.0, 53.5], [17.0, 53.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[17.0, 53.5], [19.0, 53.5], [19.0, 54.5], [17.0, 54.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[21.0, -34.5],
#       [23.0, -34.5],
#       [23.0, -33.5],
#       [21.0, -33.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[37.0, 24.5], [39.0, 24.5], [39.0, 25.5], [37.0, 25.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[21.0, 36.5], [23.0, 36.5], [23.0, 37.5], [21.0, 37.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[27.0, 35.5], [29.0, 35.5], [29.0, 36.5], [27.0, 36.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[31.0, 34.5], [33.0, 34.5], [33.0, 35.5], [31.0, 35.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[19.0, 43.5], [21.0, 43.5], [21.0, 44.5], [19.0, 44.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[21.0, 39.5], [23.0, 39.5], [23.0, 40.5], [21.0, 40.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[23.0, 41.5], [25.0, 41.5], [25.0, 42.5], [23.0, 42.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[23.0, 46.5], [25.0, 46.5], [25.0, 47.5], [23.0, 47.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[23.0, 47.5], [25.0, 47.5], [25.0, 48.5], [23.0, 48.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[25.0, 41.5], [27.0, 41.5], [27.0, 42.5], [25.0, 42.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[25.0, 43.5], [27.0, 43.5], [27.0, 44.5], [25.0, 44.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[25.0, 44.5], [27.0, 44.5], [27.0, 45.5], [25.0, 45.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[29.0, 47.5], [31.0, 47.5], [31.0, 48.5], [29.0, 48.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[31.0, 44.5], [33.0, 44.5], [33.0, 45.5], [31.0, 45.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[33.0, 46.5], [35.0, 46.5], [35.0, 47.5], [33.0, 47.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[35.0, 43.5], [37.0, 43.5], [37.0, 44.5], [35.0, 44.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[35.0, 48.5], [37.0, 48.5], [37.0, 49.5], [35.0, 49.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[37.0, 42.5], [39.0, 42.5], [39.0, 43.5], [37.0, 43.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[37.0, 43.5], [39.0, 43.5], [39.0, 44.5], [37.0, 44.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[37.0, 45.5], [39.0, 45.5], [39.0, 46.5], [37.0, 46.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[19.0, 54.5], [21.0, 54.5], [21.0, 55.5], [19.0, 55.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[23.0, 54.5], [25.0, 54.5], [25.0, 55.5], [23.0, 55.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[29.0, 49.5], [31.0, 49.5], [31.0, 50.5], [29.0, 50.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[29.0, 58.5], [31.0, 58.5], [31.0, 59.5], [29.0, 59.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[31.0, 50.5], [33.0, 50.5], [33.0, 51.5], [31.0, 51.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[35.0, 49.5], [37.0, 49.5], [37.0, 50.5], [35.0, 50.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[35.0, 53.5], [37.0, 53.5], [37.0, 54.5], [35.0, 54.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[35.0, 54.5], [37.0, 54.5], [37.0, 55.5], [35.0, 55.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[37.0, 49.5], [39.0, 49.5], [39.0, 50.5], [37.0, 50.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[37.0, 51.5], [39.0, 51.5], [39.0, 52.5], [37.0, 52.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[37.0, 54.5], [39.0, 54.5], [39.0, 55.5], [37.0, 55.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[37.0, 58.5], [39.0, 58.5], [39.0, 59.5], [37.0, 59.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[23.0, 59.5], [25.0, 59.5], [25.0, 60.5], [23.0, 60.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[23.0, 63.5], [25.0, 63.5], [25.0, 64.5], [23.0, 64.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[31.0, 68.5], [33.0, 68.5], [33.0, 69.5], [31.0, 69.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[45.0, 28.5], [47.0, 28.5], [47.0, 29.5], [45.0, 29.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[49.0, 24.5], [51.0, 24.5], [51.0, 25.5], [49.0, 25.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[39.0, 42.5], [41.0, 42.5], [41.0, 43.5], [39.0, 43.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[39.0, 44.5], [41.0, 44.5], [41.0, 45.5], [39.0, 45.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[39.0, 46.5], [41.0, 46.5], [41.0, 47.5], [39.0, 47.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[41.0, 42.5], [43.0, 42.5], [43.0, 43.5], [41.0, 43.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[45.0, 41.5], [47.0, 41.5], [47.0, 42.5], [45.0, 42.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[39.0, 50.5], [41.0, 50.5], [41.0, 51.5], [39.0, 51.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[39.0, 51.5], [41.0, 51.5], [41.0, 52.5], [39.0, 52.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[41.0, 52.5], [43.0, 52.5], [43.0, 53.5], [41.0, 53.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[43.0, 50.5], [45.0, 50.5], [45.0, 51.5], [43.0, 51.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[45.0, 51.5], [47.0, 51.5], [47.0, 52.5], [45.0, 52.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[47.0, 52.5], [49.0, 52.5], [49.0, 53.5], [47.0, 53.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[51.0, 53.5], [53.0, 53.5], [53.0, 54.5], [51.0, 54.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[55.0, 50.5], [57.0, 50.5], [57.0, 51.5], [55.0, 51.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[55.0, 58.5], [57.0, 58.5], [57.0, 59.5], [55.0, 59.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[49.0, 60.5], [51.0, 60.5], [51.0, 61.5], [49.0, 61.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[63.0, 37.5], [65.0, 37.5], [65.0, 38.5], [63.0, 38.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[59.0, 54.5], [61.0, 54.5], [61.0, 55.5], [59.0, 55.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[59.0, 58.5], [61.0, 58.5], [61.0, 59.5], [59.0, 59.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[61.0, 55.5], [63.0, 55.5], [63.0, 56.5], [61.0, 56.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[63.0, 54.5], [65.0, 54.5], [65.0, 55.5], [63.0, 55.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[63.0, 56.5], [65.0, 56.5], [65.0, 57.5], [63.0, 57.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[63.0, 57.5], [65.0, 57.5], [65.0, 58.5], [63.0, 58.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[61.0, 72.5], [63.0, 72.5], [63.0, 73.5], [61.0, 73.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[83.0, -1.5], [85.0, -1.5], [85.0, -0.5], [83.0, -0.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[85.0, 55.5], [87.0, 55.5], [87.0, 56.5], [85.0, 56.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[89.0, 55.5], [91.0, 55.5], [91.0, 56.5], [89.0, 56.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[95.0, 49.5], [97.0, 49.5], [97.0, 50.5], [95.0, 50.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[105.0, -7.5],
#       [107.0, -7.5],
#       [107.0, -6.5],
#       [105.0, -6.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[117.0, 30.5],
#       [119.0, 30.5],
#       [119.0, 31.5],
#       [117.0, 31.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[103.0, 51.5],
#       [105.0, 51.5],
#       [105.0, 52.5],
#       [103.0, 52.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[127.0, -40.5],
#       [129.0, -40.5],
#       [129.0, -39.5],
#       [127.0, -39.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[121.0, -1.5],
#       [123.0, -1.5],
#       [123.0, -0.5],
#       [121.0, -0.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[125.0, 36.5],
#       [127.0, 36.5],
#       [127.0, 37.5],
#       [125.0, 37.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[129.0, 31.5],
#       [131.0, 31.5],
#       [131.0, 32.5],
#       [129.0, 32.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[129.0, 32.5],
#       [131.0, 32.5],
#       [131.0, 33.5],
#       [129.0, 33.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[133.0, 33.5],
#       [135.0, 33.5],
#       [135.0, 34.5],
#       [133.0, 34.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[135.0, 34.5],
#       [137.0, 34.5],
#       [137.0, 35.5],
#       [135.0, 35.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[135.0, 35.5],
#       [137.0, 35.5],
#       [137.0, 36.5],
#       [135.0, 36.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[137.0, 33.5],
#       [139.0, 33.5],
#       [139.0, 34.5],
#       [137.0, 34.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[137.0, 34.5],
#       [139.0, 34.5],
#       [139.0, 35.5],
#       [137.0, 35.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[137.0, 35.5],
#       [139.0, 35.5],
#       [139.0, 36.5],
#       [137.0, 36.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[137.0, 36.5],
#       [139.0, 36.5],
#       [139.0, 37.5],
#       [137.0, 37.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[131.0, 43.5],
#       [133.0, 43.5],
#       [133.0, 44.5],
#       [131.0, 44.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[139.0, 34.5],
#       [141.0, 34.5],
#       [141.0, 35.5],
#       [139.0, 35.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[139.0, 35.5],
#       [141.0, 35.5],
#       [141.0, 36.5],
#       [139.0, 36.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[139.0, 36.5],
#       [141.0, 36.5],
#       [141.0, 37.5],
#       [139.0, 37.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[139.0, 37.5],
#       [141.0, 37.5],
#       [141.0, 38.5],
#       [139.0, 38.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[139.0, 38.5],
#       [141.0, 38.5],
#       [141.0, 39.5],
#       [139.0, 39.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[139.0, 42.5],
#       [141.0, 42.5],
#       [141.0, 43.5],
#       [139.0, 43.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[141.0, 42.5],
#       [143.0, 42.5],
#       [143.0, 43.5],
#       [141.0, 43.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[149.0, 58.5],
#       [151.0, 58.5],
#       [151.0, 59.5],
#       [149.0, 59.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[173.0, -38.5],
#       [175.0, -38.5],
#       [175.0, -37.5],
#       [173.0, -37.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[163.0, -3.5],
#       [165.0, -3.5],
#       [165.0, -2.5],
#       [163.0, -2.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[163.0, 35.5],
#       [165.0, 35.5],
#       [165.0, 36.5],
#       [163.0, 36.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[165.0, 63.5],
#       [167.0, 63.5],
#       [167.0, 64.5],
#       [165.0, 64.5]]]},
#    'id': 'RR01'},
#   {'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[159.0, 80.5],
#       [161.0, 80.5],
#       [161.0, 81.5],
#       [159.0, 81.5]]]},
#    'id': 'RR01'}]}
